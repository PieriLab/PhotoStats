# %%
import pandas as pd

# -------- settings --------
input_csv = "../data/meci_classification/benzene/meci_labels.csv"
output_csv = "../data/meci_classification/benzene/meci_labels.csv"

# string conversions: old -> new
replacements = {
    "0081_15": "Type2",
    "0070_13": "Type1",
    "0178_7": "???",
    "0178_7": "???",

   



}
# --------------------------

# read CSV
df = pd.read_csv(input_csv)

# get second column name
col = df.columns[1]

# apply replacements
df[col] = df[col].replace(replacements)

# write output
df.to_csv(output_csv, index=False)
