# %%
import pandas as pd

# -------- settings --------
input_csv = "/Users/connerbaucom/Desktop/Pieri/CTG/dim_red_comp/PhotoStats/data/meci_classification/benzene/S2S1/meci_labels_0.05_threshold.csv"
output_csv = "/Users/connerbaucom/Desktop/Pieri/CTG/dim_red_comp/PhotoStats/data/meci_classification/benzene/S2S1/meci_labels_0.05_threshold_humanlabels.csv"

# string conversions: old -> new
replacements = {
   "0185_7" : "Type_1",
   "0067_5" : "Type_2",
   "0143_2" : "Type_2",
   "0139_2" : "Type_1",
   "0043_4" : "Type_2",
   "0181_4" : "Type_1",
   "0065_3" : "Type_2",
   "0188_3": "Type_3"





   



}

df = pd.read_csv(input_csv)

col = df.columns[1]

df[col] = df[col].replace(replacements)

df.to_csv(output_csv, index=False)

# %%
Receiving coordinates from FMS
C        -1.45788611        0.21875015       -0.02131970
H        -1.81408360       -0.12439037        0.72192067
H        -2.64985120        0.58454810       -0.20877093
C        -1.04900990        1.32723162       -0.00506335
H        -1.15662499        2.29624993        0.50862745
H        -0.23899584        1.58568628       -0.70726182

# %%
 C      -1.457886108      0.218750150     -0.021319700
 H      -1.814083595     -0.124390372      0.721920665
 H      -2.649851198      0.584548100     -0.208770933
 C      -1.049009901      1.327231624     -0.005063351
 H      -1.156624988      2.296249930      0.508627449
 H      -0.238995838      1.585686280     -0.707261824
~
